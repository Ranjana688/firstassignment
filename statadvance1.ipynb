# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjana688/firstassignment/blob/main/statadvance1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.** What is a random variable in probability theory?**
#
# A random variable (RV) is a variable whose values depend on the outcomes of a random phenomenon. It allows us to quantify random outcomes and work with them mathematically.
#
# Discrete Random Variable
#
# Takes on countable values (e.g., integers).
#
# Examples:
#
# Number of heads in 5 coin tosses.
#
# Number of customers in a queue.
#
# Continuous Random Variable
#
# Takes on any value in a continuous range (uncountably infinite).
#
# Examples:
#
# Height of students in a class.
#
# Time taken to run a race.

# %% [markdown]
# 2. What are the types of random variables
# types of random variables:-
# Discrete Random Variable:- A discrete random variable can take on a finite or countably infinite set of values—usually integers
# Continuous Random Variable :- A continuous random variable can take on any value within a given interval (finite or infinite) on the real number line

# %% [markdown]
# 3. What is the difference between discrete and continuous distributions
#
# Discrete Distributions:-
# Probabilities are assigned to specific values.
#
# The sum of all probabilities equals 1.
#
# Each outcome has a non-zero probability
# Continuous Distribution:-
# Probabilities are assigned to intervals, not exact values.
#
# The probability of any exact value is zero:
# 𝑃
# (
# 𝑋
# =
# 𝑎
# )
# =
# 0
# P(X=a)=0
#
# The area under the curve (probability density function, PDF) represents probability               |

# %% [markdown]
# 4. What are probability distribution functions (PDF)
# Probability Distribution functions are mathematical functions that describe the likelihood of diffrent outcomes for a random variables. They are used to model and understand the behavior of random events.

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)
# probability distribution functions:-
# For Discrete Variables: Probability Mass Function (PMF)
# Gives the probability of an exact value:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x)
#
# Only used for discrete random variables.
# For Continuous Variables: Probability Density Function (PDF)
# Describes the relative likelihood of values in a range.
#
# The area under the curve of the PDF over an interval gives the probability:
#
# 𝑃
# (
# 𝑎
# <
# 𝑋
# <
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a<X<b)=∫
# a
# b
# ​
#  f(x)dx
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0 for any exact value
#
# Cumulative Distribution Function (CDF):-
# For Both Discrete and Continuous Variables
# Gives the probability that a random variable is less than or equal to a value:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)

# %% [markdown]
# 6.What is a discrete uniform distribution
# Dicrete uniform distribution is a symmetric probability distribution wherein each of some finite whole number 'n' of outcomes values are equally likey to be observed.

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution:-
# It models a random experiment with exactly two possible outcomes, typically labeled as success(1) and failure (0).

# %% [markdown]
# 8. What is the binomial distribution, and how is it used in probability.
#
# A random variable
# 𝑋
# X follows a binomial distribution if:
#
# There are n independent trials.
#
# Each trial results in success (with probability
# 𝑝
# p) or failure (with probability
# 𝑞
# =
# 1
# −
# 𝑝
# q=1−p).
#
# 𝑋
# X counts the number of successes in the
# 𝑛
# n trials.
#
# 𝑋
# ∼
# Bin
# (
# 𝑛
# ,
# 𝑝
# )
# X∼Bin(n,p)
# Applications of Binomial Distribution:
# Quality control:Probability of finding a certain number of defective products in a sample.
#
# Medical trials:Number of patients responding to a treatment out of a fixed group.
#
# Elections:Probability that a candidate gets a certain number of votes from a group of voters.
#
# Games/experiments:Number of times a player wins in repeated identical games.

# %% [markdown]
# 9. What is the Poisson distribution and where is it applied
#
# The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time or space if these events occur with a known constant mean rate and independently of the time since the last event

# %% [markdown]
# 10.What is a continuous uniform distribution
#
# A continuous uniform distribution is a probability distribution where a continuous random variable has an equal probability of taking any value within a specified range [a, b]. This means the probability density function (PDF) is constant within that range and zero outside of it. Essentially, every outcome within the range is equally likely to occur.

# %% [markdown]
# 11. What are the characteristics of a normal distribution
#
# A normal distribution, also known as a Gaussian distribution or bell curve, is characterized by several key features. It's symmetric around its mean, meaning the left and right sides of the curve are mirror images. The mean, median, and mode are all equal, and located at the center of the distribution. The curve is bell-shaped, with the highest point at the mean and tapering off equally in both directions. Furthermore, the total area under the curve equals 1, and the distribution is fully defined by its mean and standard deviation

# %% [markdown]
# 12. What is the standard normal distribution, and why is it important
#
# The standard normal distribution is a specific type of normal distribution where the mean is 0 and the standard deviation is 1. It's a crucial concept in statistics because it allows us to compare data from different normal distributions and calculate probabilities related to those distributions

# %% [markdown]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# The Central Limit Theorem (CLT) states that the distribution of sample means will approximate a normal distribution, regardless of the original population's distribution, as long as the sample size is sufficiently large. This is critical in statistics because it allows us to make inferences about population parameters (like the mean) using sample data, even when the population distribution is unknown or non-normal.
# Here's a more detailed explanation:
# What it means:
# Imagine you have a population with a very skewed distribution (e.g., income distribution). If you take many random samples from this population and calculate the mean of each sample, those sample means will, according to the CLT, tend to cluster around the population mean and follow a normal distribution.
# Why it's important:
# Many statistical methods rely on the assumption of a normal distribution. If the data you are working with doesn't appear to be normally distributed, you can still use these methods with confidence if you have a large enough sample size due to the CLT

# %% [markdown]
# 14. How does the Central Limit Theorem relate to the normal distribution?
#
# The central limit theorem (CLT) explains the relationship between the normal distribution and sample means. It states that the distribution of sample means will approach a normal distribution, regardless of the shape of the original population distribution, as the sample size gets larger

# %% [markdown]
# 15. What is the application of Z statistics in hypothesis testing?
#
# Z-statistics, calculated using a Z-test, are applied in hypothesis testing to determine if there's a significant difference between a sample's mean and a population's mean, or between the means of two independent samples. This is particularly useful when the population variance is known, or when dealing with large sample sizes (typically n ≥ 30)

# %% [markdown]
# 16.  How do you calculate a Z-score, and what does it represent?
#
# A z-score, also known as a standard score, indicates how many standard deviations a data point is away from the mean of a dataset. It's calculated by subtracting the mean from the data point and dividing the result by the standard deviation

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?
#
# In statistics, point estimates and interval estimates are two fundamental ways to estimate unknown population parameters using sample data
# Point Estimates:
# A point estimate is a single value calculated from sample data that is used to estimate an unknown population parameter.
# For example, the sample mean is a point estimate for the population mean, and the sample proportion is a point estimate for the population proportion.
# Point estimates are straightforward but don't provide information about the uncertainty or variability in the estimation.
# Interval Estimates:
# An interval estimate provides a range of values, called a confidence interval, within which the population parameter is likely to lie, with a specified level of confidence.
# For example, a 95% confidence interval for the population mean would be a range of values calculated from the sample data, such that we are 95% confident that the true population mean falls within that range.

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis?
#
# Confidence intervals in statistical analysis are crucial because they provide a range of plausible values for an unknown population parameter, offering a more informative measure of uncertainty than a single point estimate

# %% [markdown]
# 19.  What is the relationship between a Z-score and a confidence interval?
# A Z-score and a confidence interval are related concepts in statistics. The Z-score, specifically the critical Z-score, is used to determine the margin of error, which in turn defines the width of the confidence interval. Essentially, the confidence interval provides a range of values likely to contain the true population parameter, and the Z-score helps define the boundaries of that range.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?
# Z-scores are used to compare data from different distributions by standardizing the values. This means converting raw scores into a common scale based on standard deviations from the mean, allowing for direct comparison regardless of the original scale

# %% [markdown]
# 21. What are the assumptions for applying the Central Limit Theorem?
#
# The Central Limit Theorem (CLT) requires a few key assumptions to be met for the sampling distribution of sample means to approximate a normal distribution. These include: random sampling, independence of samples, a sufficiently large sample size, and sometimes, that the sample size is less than 10% of the population when sampling without replacement.

# %% [markdown]
# **practical questions.**

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value

# %%
import random

# Generate a random variable from 1 to 6 (like a dice roll)
random_variable = random.randint(1, 6)

print("Random Discrete Variable (Die Roll):", random_variable)
# Out:
# Random Discrete Variable (Die Roll): 2

# %% [markdown]
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution (e.g., 1 to 6 inclusive)
low = 1
high = 7
dist = randint(low, high)


x = np.arange(low, high)

pmf = dist.pmf(x)


plt.figure(figsize=(8, 5))
plt.stem(x, pmf, use_line_collection=True)
plt.title("Discrete Uniform Distribution PMF (1 to 6)")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.ylim(0, 1)
plt.grid(True)
plt.xticks(x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-226193883.py in <cell line: 0>()
#      15
#      16 plt.figure(figsize=(8, 5))
# ---> 17 plt.stem(x, pmf, use_line_collection=True)
#      18 plt.title("Discrete Uniform Distribution PMF (1 to 6)")
#      19 plt.xlabel("Outcome")
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the PDF of a Bernoulli distribution.

    Parameters:
        x (int): The outcome (0 or 1)
        p (float): The probability of success (0 ≤ p ≤ 1)

    Returns:
        float: Probability of the outcome x
    """
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        return 0

# Ex
p = 0.7  # Probability of success
print("P(X=0):", bernoulli_pdf(0, p))
print("P(X=1):", bernoulli_pdf(1, p))
# Out:
# P(X=0): 0.30000000000000004
# P(X=1): 0.7

# %% [markdown]
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10
p = 0.5
size = 10000


samples = np.random.binomial(n, p, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(-0.5, n + 1.5, 1), density=True, edgecolor='black', alpha=0.75)
plt.title(f"Histogram of Binomial Distribution (n={n}, p={p})")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.xticks(range(n + 1))
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson


lambda_val = 4
x = np.arange(0, 15)


pmf = poisson.pmf(x, mu=lambda_val)

# Plot the Poisson PMF
plt.figure(figsize=(8, 5))
plt.stem(x, pmf, use_line_collection=True)
plt.title(f"Poisson Distribution (λ = {lambda_val})")
plt.xlabel("Number of Events (k)")
plt.ylabel("Probability P(X = k)")
plt.grid(True)
plt.show()

# %% [markdown]
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint
low = 1
high = 7
dist = randint(low, high)
x = np.arange(low - 1, high + 1)

cdf_values = dist.cdf(x)
plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='post', color='blue', label='CDF')
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.xticks(np.arange(low - 1, high + 1))
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

# %%
import numpy as np
import matplotlib.pyplot as plt


a = 2
b = 5
size = 10000
samples = np.random.uniform(a, b, size)
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=50, density=True, alpha=0.6, edgecolor='black', label='Sampled Histogram')
plt.plot([a, b], [1/(b - a)] * 2, 'r--', linewidth=2, label='Theoretical PDF')
plt.title(f"Continuous Uniform Distribution U({a}, {b})")
plt.xlabel("Value")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# 8. Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


mean = 0
std_dev = 1
size = 10000
samples = np.random.normal(loc=mean, scale=std_dev, size=size)
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sampled Histogram')
x = np.linspace(min(bins), max(bins), 300)
pdf = norm.pdf(x, loc=mean, scale=std_dev)
plt.plot(x, pdf, 'r-', linewidth=2, label='Theoretical PDF')
plt.title(f"Normal Distribution (μ = {mean}, σ = {std_dev})")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 9.Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculates Z-scores for the given dataset and plots them.

    Parameters:
        data (list or np.array): A numeric dataset

    Returns:
        z_scores (np.array): The calculated Z-scores
    """
    data = np.array(data)
    mean = np.mean(data)
    std_dev = np.std(data)

    if std_dev == 0:
        raise ValueError("Standard deviation is zero. Z-scores cannot be computed.")


    z_scores = (data - mean) / std_dev
    plt.figure(figsize=(8, 5))
    plt.plot(z_scores, 'o-', color='blue', label='Z-scores')
    plt.axhline(0, color='gray', linestyle='--')
    plt.axhline(1, color='green', linestyle='--', label='±1 SD')
    plt.axhline(-1, color='green', linestyle='--')
    plt.axhline(2, color='orange', linestyle='--', label='±2 SD')
    plt.axhline(-2, color='orange', linestyle='--')
    plt.axhline(3, color='red', linestyle='--', label='±3 SD')
    plt.axhline(-3, color='red', linestyle='--')
    plt.title("Z-scores of Dataset")
    plt.xlabel("Data Point Index")
    plt.ylabel("Z-score")
    plt.grid(True)
    plt.legend()
    plt.show()

    return z_scores

# Ex
data = np.random.normal(loc=50, scale=10, size=30)
z_scores = calculate_and_plot_z_scores(data)

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define a non-normal distribution (Exponential)
population = np.random.exponential(scale=2.0, size=100000)  # population with λ=0.5

# Step 2: Parameters for CLT simulation
sample_size = 30
num_samples = 1000
sample_means = []

# Step 3: Draw repeated samples and store their means
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=True)
    sample_means.append(np.mean(sample))

# Step 4: Plot the original population and the distribution of sample means
plt.figure(figsize=(14, 5))

# Plot 1: Histogram of the original (non-normal) population

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define the normal distribution parameters
true_mean = 100
true_std = 15
population_size = 100000

# Create a population that is normally distributed
population = np.random.normal(loc=true_mean, scale=true_std, size=population_size)

# Step 2: CLT Simulation Parameters
sample_size = 30           # number of observations per sample
num_samples = 1000         # number of samples to draw
sample_means = []

# Step 3: Draw multiple samples and compute their means
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=True)
    sample_means.append(np.mean(sample))

# Step 4: Plot the sampling distribution of sample means
plt.figure(figsize=(14, 5))

# Plot 1: Original population distribution
plt.subplot(1, 2, 1)
plt.hist(population, bins=50, color='lightcoral', edgecolor='black', density=True)
plt.title("Original Normal Population")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)

# Plot 2: Sampling distribution of sample means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=30, color='lightblue', edgecolor='black', density=True)
plt.title(f"Sampling Distribution of Sample Means\n(sample size = {sample_size}, samples = {num_samples})")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# 12.  Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculates and plots the standard normal distribution (mean = 0, std = 1).
    """

    x = np.linspace(-4, 4, 500)
    pdf = norm.pdf(x, loc=0, scale=1)
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, 'b-', label='Standard Normal PDF')
    plt.fill_between(x, pdf, color='skyblue', alpha=0.4)
    plt.title("Standard Normal Distribution (μ = 0, σ = 1)")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.legend()
    plt.show()

# Ex
plot_standard_normal_distribution()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
n = 10
p = 0.5
size = 20
random_vars = np.random.binomial(n, p, size)
print("Generated Binomial Random Variables:")
print(random_vars)
x = np.arange(0, n + 1)
pmf_values = binom.pmf(x, n, p)
print("\nPMF Values (P(X = x)):")
for xi, pi in zip(x, pmf_values):
    print(f"P(X = {xi}) = {pi:.4f}")
plt.figure(figsize=(8, 5))
plt.stem(x, pmf_values, basefmt=" ", use_line_collection=True)
plt.title(f"Binomial Distribution PMF (n={n}, p={p})")
plt.xlabel("Number of Successes (x)")
plt.ylabel("Probability P(X = x)")
plt.xticks(x)
plt.grid(True)
plt.show()
# Out:
# Generated Binomial Random Variables:
# [5 5 6 6 3 6 5 3 2 5 3 5 6 5 4 5 2 4 5 4]
#
# PMF Values (P(X = x)):
# P(X = 0) = 0.0010
# P(X = 1) = 0.0098
# P(X = 2) = 0.0439
# P(X = 3) = 0.1172
# P(X = 4) = 0.2051
# P(X = 5) = 0.2461
# P(X = 6) = 0.2051
# P(X = 7) = 0.1172
# P(X = 8) = 0.0439
# P(X = 9) = 0.0098
# P(X = 10) = 0.0010
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-803002780.py in <cell line: 0>()
#      23 # Step 4: Plot PMF
#      24 plt.figure(figsize=(8, 5))
# ---> 25 plt.stem(x, pmf_values, basefmt=" ", use_line_collection=True)
#      26 plt.title(f"Binomial Distribution PMF (n={n}, p={p})")
#      27 plt.xlabel("Number of Successes (x)")
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %% [markdown]
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std_dev):
    """
    Calculates the Z-score for a data point.

    Parameters:
        x (float): The data point
        mean (float): Mean of the population
        std_dev (float): Standard deviation of the population

    Returns:
        float: Z-score
    """
    return (x - mean) / std_dev

def plot_standard_normal_with_z(z):
    """
    Plots the standard normal distribution and highlights the Z-score area.

    Parameters:
        z (float): Z-score to highlight
    """
    x = np.linspace(-4, 4, 500)
    y = norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal PDF', color='blue')
    plt.fill_between(x, 0, y, where=(x <= z), color='skyblue', alpha=0.5,
                     label=f'Area ≤ Z = {z:.2f}')
    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')
    plt.title('Standard Normal Distribution with Z-score')
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.legend()
    plt.show()

# Example: given data point
x_value = 82
mean = 75
std_dev = 5

# Step 1: Calculate Z-score
z = calculate_z_score(x_value, mean, std_dev)
print(f"Z-score for x = {x_value}: {z:.2f}")

# Step 2: Calculate cumulative probability (area under curve up to Z)
cdf_value = norm.cdf(z)
print(f"Probability that Z ≤ {z:.2f}: {cdf_value:.4f}")

# Step 3: Visualize
plot_standard_normal_with_z(z)
# Out:
# Z-score for x = 82: 1.40
# Probability that Z ≤ 1.40: 0.9192

# %% [markdown]
# 16. Implement hypothesis testing using Z-statistics for a sample dataset

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_mean, population_mean, population_std, n, alpha=0.05, tail='two'):

    standard_error = population_std / np.sqrt(n)
    z_stat = (sample_mean - population_mean) / standard_error

    if tail == 'two':
        p_value = 2 * (1 - norm.cdf(abs(z_stat)))
    elif tail == 'right':
        p_value = 1 - norm.cdf(z_stat)
    elif tail == 'left':
        p_value = norm.cdf(z_stat)
    else:
        raise ValueError("Invalid tail type. Use 'two', 'left', or 'right'.")


    if p_value < alpha:
        result = "Reject the null hypothesis (H₀)"
    else:
        result = "Fail to reject the null hypothesis (H₀)"

    return z_stat, p_value, result

# Ex
sample_mean = 104
population_mean = 100
population_std = 15
n = 50
alpha = 0.05

z_stat, p_value, decision = z_test(sample_mean, population_mean, population_std, n, alpha, tail='two')

print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Decision: {decision}")
# Out:
# Z-statistic: 1.8856
# P-value: 0.0593
# Decision: Fail to reject the null hypothesis (H₀)

# %% [markdown]
# 17. Create a confidence interval for a dataset using Python and interpret the result

# %%
import numpy as np
from scipy.stats import norm

def confidence_interval(data, confidence=0.95):

    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)  # sample std dev & standard error
    z = norm.ppf((1 + confidence) / 2)

    margin = z * std_err
    return (mean - margin, mean + margin)

# 🔢 Example data: sample of test scores
sample_data = [88, 92, 85, 91, 87, 89, 94, 90, 86, 93]

# Compute 95% confidence interval
ci_low, ci_high = confidence_interval(sample_data, confidence=0.95)
mean_sample = np.mean(sample_data)

# 🖨️ Print result
print(f"Sample Mean: {mean_sample:.2f}")
print(f"95% Confidence Interval: ({ci_low:.2f}, {ci_high:.2f})")
# Out:
# Sample Mean: 89.50
# 95% Confidence Interval: (87.62, 91.38)

# %% [markdown]
# 18. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy.stats import norm

def confidence_interval(data, confidence=0.95):

    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)  # sample standard error
    z = norm.ppf((1 + confidence) / 2)           # z-score for desired confidence
    margin = z * std_err

    return mean - margin, mean + margin, mean

# Step 1: Simulate normal data
np.random.seed(42)  # for reproducibility
mu = 50             # true population mean
sigma = 10          # true population std dev
n = 100             # sample size

sample_data = np.random.normal(loc=mu, scale=sigma, size=n)
ci_low, ci_high, sample_mean = confidence_interval(sample_data, confidence=0.95)
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval for the Mean: ({ci_low:.2f}, {ci_high:.2f})")
# Out:
# Sample Mean: 48.96
# 95% Confidence Interval for the Mean: (47.18, 50.74)

# %% [markdown]
# 19. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
mean = 0
std_dev = 1
x_values = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 500)
pdf_values = norm.pdf(x_values, loc=mean, scale=std_dev)
plt.figure(figsize=(8, 5))
plt.plot(x_values, pdf_values, color='blue', label=f'N({mean}, {std_dev}²)')
plt.fill_between(x_values, pdf_values, alpha=0.3, color='skyblue')
plt.title("Probability Density Function of Normal Distribution")
plt.xlabel("x")
plt.ylabel("Density")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 20. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson
lambda_val = 4
x = np.arange(0, 15)
cdf_values = poisson.cdf(x, mu=lambda_val)
k = 5
prob_k = poisson.cdf(k, mu=lambda_val)
print(f"P(X ≤ {k}) for Poisson(λ={lambda_val}) = {prob_k:.4f}")
plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='post', label='Poisson CDF', color='blue')
plt.scatter(k, prob_k, color='red', zorder=5, label=f'P(X ≤ {k}) = {prob_k:.2f}')
plt.title(f"Cumulative Distribution Function (CDF) of Poisson(λ = {lambda_val})")
plt.xlabel("Number of Events (k)")
plt.ylabel("P(X ≤ k)")
plt.xticks(x)
plt.ylim(0, 1.05)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# P(X ≤ 5) for Poisson(λ=4) = 0.7851

# %% [markdown]
# 21. Simulate a random variable using a continuous uniform distribution and calculate its expected value

# %%
import numpy as np
a = 10
b = 20

x = np.random.uniform(a, b)
expected_value = (a + b) / 2
print(f"Simulated Uniform({a}, {b}) value: {x:.4f}")
print(f"Theoretical Expected Value E[X] = (a + b) / 2 = {expected_value:.4f}")
# Out:
# Simulated Uniform(10, 20) value: 14.1741
# Theoretical Expected Value E[X] = (a + b) / 2 = 15.0000

# %% [markdown]
# 22. Write a Python program to compare the standard deviations of two datasets and visualize the difference

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=100)
data2 = np.random.normal(loc=50, scale=15, size=100)
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.bar(['Dataset 1', 'Dataset 2'], [std1, std2], color=['steelblue', 'salmon'])
plt.title("Standard Deviation Comparison")
plt.ylabel("Standard Deviation")
plt.grid(axis='y')
plt.subplot(1, 2, 2)
plt.hist(data1, bins=20, alpha=0.6, label='Dataset 1 (std ~5)', color='steelblue', edgecolor='black')
plt.hist(data2, bins=20, alpha=0.6, label='Dataset 2 (std ~15)', color='salmon', edgecolor='black')
plt.title("Histogram of Two Datasets")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.54
# Standard Deviation of Dataset 2: 14.31

# %% [markdown]
# 23. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

# %%
import numpy as np

# Step 1: Generate data from a normal distribution
np.random.seed(42)
mean = 100
std_dev = 15
n = 100
data = np.random.normal(loc=mean, scale=std_dev, size=n)
data_range = np.max(data) - np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1
print(f"Sample Size: {n}")
print(f"Data Range: {data_range:.2f}")
print(f"Q1 (25th percentile): {q1:.2f}")
print(f"Q3 (75th percentile): {q3:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Sample Size: 100
# Data Range: 67.08
# Q1 (25th percentile): 90.99
# Q3 (75th percentile): 106.09
# Interquartile Range (IQR): 15.10

# %% [markdown]
# 24. Implement Z-score normalization on a dataset and visualize its transformation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate a sample dataset
np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=100)  # mean=50, std=10
mean = np.mean(data)
std = np.std(data)
z_normalized = (data - mean) / std
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(data, bins=20, color='skyblue', edgecolor='black')
plt.title("Original Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.axvline(mean, color='red', linestyle='--', label=f"Mean = {mean:.2f}")
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.hist(z_normalized, bins=20, color='lightgreen', edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.axvline(0, color='red', linestyle='--', label="Mean = 0")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
print(f"Original Mean: {mean:.2f}, Std Dev: {std:.2f}")
print(f"Normalized Mean: {np.mean(z_normalized):.2f}, Std Dev: {np.std(z_normalized):.2f}")
# Out:
# Original Mean: 50.60, Std Dev: 10.08
# Normalized Mean: 0.00, Std Dev: 1.00
