# %% [markdown]
# 1.  Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales:-
#
#
# 1. Qualitative data describes qualities or characteristics. It cannot be measured numerically but can be categorized
# a. Nominal Scale (Named categories)Categorizes data without any order or ranking.
#
# b. Ordinal Scale (Ordered categories)Categorizes data with a meaningful order, but the intervals between categories are not equal or known.
#
# 2. Quantitative Data (Numerical Data)
# Quantitative data expresses numeric values and can be measured or counted.
#
# a. Interval Scale
# b. Ratio Scale Like interval data, but with a meaningful zero, allowing for a full range of mathematical operations.

# %% [markdown]
# 2.  What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate
#
# Measures of Central Tendency
# Measures of central tendency describe the center or typical value in a dataset. The three main measures are:
#
# Mean (Average)
# Mean=
# Number of values/Sum of all values
#
# Median (Middle Value)
# middle value
#
# Mode (Most Frequent Value)
# most frequesnt value

# %% [markdown]
# 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data
#
# Dispersion refers to the degree of spread or variability in a dataset. It tells us how much the data values differ from each other and from the central tendency (like the mean or median)
# importance of dispersion:-
# Range – Difference between the highest and lowest value
# Variance – Average squared deviation from the mean
# Standard Deviation – Square root of variance
# Interquartile Range (IQR) – Difference between the 75th and 25th percentile

# %% [markdown]
# 4.What is a box plot, and what can it tell you about the distribution of data?
#
#
# A box plot (also known as a box-and-whisker plot) is a graphical representation of the distribution of a dataset. It shows the spread, central value, and skewness using five summary statistics:
#
# Minimum (lowest value excluding outliers)
# First Quartile (Q1) – 25th percentile
# Median (Q2) – 50th percentile
# Third Quartile (Q3) – 75th percentile
# Maximum (highest value excluding outliers)

# %% [markdown]
# 5.  Discuss the role of random sampling in making inferences about populations
#
# Role of Random Sampling in Making Inferences About Populations
# Random sampling is a fundamental technique in statistics used to select a subset (sample) from a larger group (population) in such a way that every individual has an equal chance of being selected
# 1. Ensures Representativeness
# 2. Supports Generalization (Inference)
# 3. Allows Use of Probability Theory

# %% [markdown]
# 6.  Explain the concept of skewness and its types. How does skewness affect the interpretation of data
#
# Skewness is a statistical measure that describes the asymmetry or lack of symmetry in the distribution of data. It tells us whether the data values are concentrated more on one side of the mean than the other.
# In a perfectly symmetrical distribution, the left and right sides are mirror images. But in real-world data, distributions often lean (or "skew") either to the left or right

# %% [markdown]
# 7. What is the interquartile range (IQR), and how is it used to detect outliers
#
#
# The Interquartile Range (IQR) is a measure of statistical dispersion—it tells you how spread out the middle 50% of your data is.
# It is calculated as:
# IQR = Q3 - Q1
#
# Q1 (First Quartile): The 25th percentile (25% of data is below this value)
# Q3 (Third Quartile): The 75th percentile (75% of data is below this value)

# %% [markdown]
# 8.  Discuss the conditions under which the binomial distribution is used
#
#
# The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials of a binary.
#
# Conditions for using the binomial Distribution
# 1. Fixed number of trial(n)
# 2. only two possible outcomes per trial
# 3. Constant probability of success
# 4. Independent trial

# %% [markdown]
# 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule)
#
# The normal distribution (also called the Gaussian distribution) is a continuous probability distribution that is bell-shaped and symmetric about its mean. It is one of the most widely used distributions in statistics
#
# The Empirical Rule (68-95-99.7 Rule)
# The Empirical Rule describes how data is spread in a normal distribution in terms of standard deviations (σ) from the mean (μ)

# %% [markdown]
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event
#
#
# Poisson Process: Real-Life Example & Probability Calculation
# The Poisson process is used to model the number of times an event occurs in a fixed interval of time or space when:
# Events occur randomly and independently
# The average rate of occurrence (λ) is constant

# %% [markdown]
# 11.  Explain what a random variable is and differentiate between discrete and continuous random variables
#
#
# A random variable is a numerical quantity whose value depends on the outcome of a random experiment.
# It assigns a numerical value to each possible outcome in a probability experiment
# types
# a. Discrete random variable
# b. Continous random variable

# %% [markdown]
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results
#
# emaple data set
# student    study hours         exam score
# A           2               65
# B           3               70
# C           5               75
# D           7               85
# E           9               95
#
#
# +
# 75
# +
# 85
# +
# 95
# 5
# =
# 78
# X
# ˉ
#  =
# 5
# 2+3+5+7+9
# ​
#  =5.2,
# Y
# ˉ
#  =
# 5
# 65+70+75+85+95
# ​
#  =78
# Step 2: Compute covariance:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 𝑛
# −
# 1
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# Cov(X,Y)=
# n−1
# 1
# ​
#  ∑(X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 4
# [
# (
# 2
# −
# 5.2
# )
# (
# 65
# −
# 78
# )
# +
# (
# 3
# −
# 5.2
# )
# (
# 70
# −
# 78
# )
# +
# (
# 5
# −
# 5.2
# )
# (
# 75
# −
# 78
# )
# +
# (
# 7
# −
# 5.2
# )
# (
# 85
# −
# 78
# )
# +
# (
# 9
# −
# 5.2
# )
# (
# 95
# −
# 78
# )
# ]
# =
# 1
# 4
# [
# (
# −
# 3.2
# )
# (
# −
# 13
# )
# +
# (
# −
# 2.2
# )
# (
# −
# 8
# )
# +
# (
# −
# 0.2
# )
# (
# −
# 3
# )
# +
# (
# 1.8
# )
# (
# 7
# )
# +
# (
# 3.8
# )
# (
# 17
# )
# ]
# =
# 1
# 4
# [
# 41.6
# +
# 17.6
# +
# 0.6
# +
# 12.6
# +
# 64.6
# ]
# =
# 137
# 4
# =
# ∗
# ∗
# 34.25
# ∗
# ∗
# Cov(X,Y)
# ​
#
# =
# 4
# 1
# ​
#  [(2−5.2)(65−78)+(3−5.2)(70−78)+
# (5−5.2)(75−78)+(7−5.2)(85−78)+(9−5.2)(95−78)]
# =
# 4
# 1
# ​
#  [(−3.2)(−13)+(−2.2)(−8)+(−0.2)(−3)+(1.8)(7)+(3.8)(17)]
# =
# 4
# 1
# ​
#  [41.6+17.6+0.6+12.6+64.6]=
# 4
# 137
# ​
#  =∗∗34.25∗∗
# ​
#
# ✅ Covariance = 34.25
